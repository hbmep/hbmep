# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import os
import logging
from pathlib import Path

import arviz as az
import numpyro

from hb_mep.config import HBMepConfig
from hb_mep.data_access import DataClass
# from hb_mep.models.rats import MixtureModel
from hb_mep.models.rats.utils import load_data
from hb_mep.utils import plot

numpyro.set_platform("cpu")
numpyro.set_host_device_count(12)
numpyro.enable_x64()

PARENT_PATH = Path(os.getcwd()).parent.parent.absolute()
FORMAT = "%(asctime)s - %(name)s - %(levelname)s - %(message)s"
logging.basicConfig(format=FORMAT, level=logging.INFO)


import jax
import jax.numpy as jnp
import numpy as np
import pandas as pd

import numpyro
import numpyro.distributions as dist
from numpyro.distributions.mixtures import MixtureGeneral
from numpyro.infer import MCMC, NUTS
from numpyro.diagnostics import hpdi

from hb_mep.config import HBMepConfig
from hb_mep.models.baseline import Baseline
from hb_mep.models.utils import Site as site
from hb_mep.utils import timing
from hb_mep.utils.constants import (
    INTENSITY,
    RESPONSE,
    PARTICIPANT,
    FEATURES
)

logger = logging.getLogger(__name__)

# %% [markdown]
# #### Load config

# %%
config = HBMepConfig()
config.CURRENT_PATH = PARENT_PATH

# %% [markdown]
# #### Load data and preprocess

# %%
data = DataClass(config)

a, b = 1, 2
subset = range(a, b)

df, mat, time = load_data(subset, data)
df, encoder_dict = data.build(df)
# Out:
# 2023-06-11 23:39:25,125 - hb_mep.utils.utils - INFO - func:load_data took: 0.14 sec
# 2023-06-11 23:39:25,126 - hb_mep.data_access.core - INFO - Processing data ...
# 2023-06-11 23:39:25,133 - hb_mep.utils.utils - INFO - func:preprocess took: 0.01 sec
# 2023-06-11 23:39:25,134 - hb_mep.utils.utils - INFO - func:build took: 0.01 sec

# %% [markdown]
# ### Mixture Model

# %%
class MixtureModel(Baseline):
    def __init__(self, config: HBMepConfig):
        super(MixtureModel, self).__init__(config=config)
        self.name = "Mixture_Model"

        self.columns = [PARTICIPANT] + FEATURES
        self.x = np.linspace(0, 450, 1000)

    def _model(self, intensity, participant, feature0, feature1, response_obs=None):
        n_data = intensity.shape[0]
        n_participant = np.unique(participant).shape[0]
        n_feature0 = np.unique(feature0).shape[0]
        n_feature1 = np.unique(feature1).shape[0]

        with numpyro.plate("n_participant", n_participant, dim=-1):
            """ Hyper-priors """
            a_mean = numpyro.sample(
                site.a_mean,
                dist.TruncatedNormal(150, 50, low=0)
            )
            a_scale = numpyro.sample(site.a_scale, dist.HalfNormal(20))

            b_scale = numpyro.sample(site.b_scale, dist.HalfNormal(0.1))

            h_scale = numpyro.sample("h_scale", dist.HalfNormal(10))
            v_scale = numpyro.sample("v_scale", dist.HalfNormal(10))

            lo_scale = numpyro.sample(site.lo_scale, dist.HalfNormal(0.01))

            noise_offset_scale = numpyro.sample(
                site.noise_offset_scale,
                dist.HalfCauchy(0.05)
            )
            noise_slope_scale = numpyro.sample(
                site.noise_slope_scale,
                dist.HalfCauchy(0.05)
            )

            with numpyro.plate("n_feature0", n_feature0, dim=-2):
                with numpyro.plate("n_feature1", n_feature1, dim=-3):
                    """ Priors """
                    a = numpyro.sample(
                        site.a,
                        dist.TruncatedNormal(a_mean, a_scale, low=0)
                    )
                    b = numpyro.sample(site.b, dist.HalfNormal(b_scale))

                    h = numpyro.sample("h", dist.HalfNormal(h_scale))
                    v = numpyro.sample("v", dist.HalfNormal(v_scale))

                    lo = numpyro.sample(site.lo, dist.HalfNormal(lo_scale))

                    noise_offset = numpyro.sample(
                        site.noise_offset,
                        dist.HalfCauchy(noise_offset_scale)
                    )
                    noise_slope = numpyro.sample(
                        site.noise_slope,
                        dist.HalfCauchy(noise_slope_scale)
                    )

                    # noise_mixture = numpyro.sample(
                    #     "noise_mixture",
                    #     dist.HalfCauchy(0.2)
                    # )

                    q = numpyro.sample("q", dist.Beta(1, 48))

        """ Transformed Parameters """
        A = numpyro.deterministic("A", a[feature1, feature0, participant])
        B = numpyro.deterministic("B", b[feature1, feature0, participant])

        H = numpyro.deterministic("H", h[feature1, feature0, participant])
        V = numpyro.deterministic("V", v[feature1, feature0, participant])

        LO = numpyro.deterministic("LO", lo[feature1, feature0, participant])

        NOISE_OFFSET = numpyro.deterministic(
            "NOISE_OFFSET", noise_offset[feature1, feature0, participant]
        )
        NOISE_SLOPE = numpyro.deterministic(
            "NOISE_SLOPE", noise_slope[feature1, feature0, participant]
        )

        # NOISE_MIXTURE = numpyro.deterministic(
        #     "NOISE_MIXTURE", noise_mixture[feature1, feature0, participant]
        # )

        Q = numpyro.deterministic("Q", q[feature1, feature0, participant])

        """ Model """
        mean = numpyro.deterministic(
            site.mean,
            (LO + jnp.maximum(
                0,
                -1 + (
                    (H + 1) / \
                    jnp.power(
                        1 + (jnp.power(1 + H, V) - 1) * jnp.exp(-B * (intensity - A)),
                        1 / V
                    )
                )
            ) - Q * 10 * jnp.sqrt(2 / jnp.pi)) / (1 - Q)
        )

        sigma = numpyro.deterministic("sigma", NOISE_OFFSET + NOISE_SLOPE * mean)

        fg_dist = dist.TruncatedNormal(mean, sigma, low=0)
        bg_dist = dist.TruncatedNormal(0, 10, low=0)

        """ Mixture """
        component_distributions = [fg_dist, bg_dist]

        mixing_distribution = dist.Categorical(probs=jnp.array([1 - Q, Q]).T)

        mixture = MixtureGeneral(
            component_distributions=component_distributions,
            mixing_distribution=mixing_distribution
        )

        """ Observation """
        with numpyro.plate(site.data, n_data):
            return numpyro.sample(site.obs, mixture, obs=response_obs)

    @timing
    def run_inference(self, df: pd.DataFrame) -> tuple[numpyro.infer.mcmc.MCMC, dict]:
        """
        Run MCMC inference
        """
        response = df[RESPONSE].to_numpy().reshape(-1,)
        participant = df[PARTICIPANT].to_numpy().reshape(-1,)
        feature0 = df[FEATURES[0]].to_numpy().reshape(-1,)
        feature1 = df[FEATURES[1]].to_numpy().reshape(-1,)
        intensity = df[INTENSITY].to_numpy().reshape(-1,)

        # MCMC
        nuts_kernel = NUTS(self._model)
        mcmc = MCMC(nuts_kernel, **self.config.MCMC_PARAMS)
        rng_key = jax.random.PRNGKey(self.random_state)
        logger.info(f"Running inference with {self.name} ...")
        mcmc.run(rng_key, intensity, participant, feature0, feature1, response)
        posterior_samples = mcmc.get_samples()

        return mcmc, posterior_samples

    @timing
    def run_inference(self, df: pd.DataFrame) -> tuple[numpyro.infer.mcmc.MCMC, dict]:
        """
        Run MCMC inference
        """
        response = df[RESPONSE].to_numpy().reshape(-1,)
        participant = df[PARTICIPANT].to_numpy().reshape(-1,)
        feature0 = df[FEATURES[0]].to_numpy().reshape(-1,)
        feature1 = df[FEATURES[1]].to_numpy().reshape(-1,)
        intensity = df[INTENSITY].to_numpy().reshape(-1,)

        # MCMC
        nuts_kernel = NUTS(self._model)
        mcmc = MCMC(nuts_kernel, **self.config.MCMC_PARAMS)
        rng_key = jax.random.PRNGKey(self.random_state)
        logger.info(f"Running inference with {self.name} ...")
        mcmc.run(rng_key, intensity, participant, feature0, feature1, response)
        posterior_samples = mcmc.get_samples()

        return mcmc, posterior_samples

# %% [markdown]
# #### Initialize model

# %%
model = MixtureModel(config)

# model.predictive_check(df=df, n_ppdm=1000, n_ppdo=1);
# Out:
# 2023-06-11 23:39:25,419 - jax._src.xla_bridge - INFO - Unable to initialize backend 'tpu_driver': NOT_FOUND: Unable to find driver in registry given worker:
# 2023-06-11 23:39:25,419 - jax._src.xla_bridge - INFO - Unable to initialize backend 'cuda': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# 2023-06-11 23:39:25,420 - jax._src.xla_bridge - INFO - Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# 2023-06-11 23:39:25,420 - jax._src.xla_bridge - INFO - Unable to initialize backend 'tpu': INVALID_ARGUMENT: TpuPlatform is not available.
# 2023-06-11 23:39:25,420 - jax._src.xla_bridge - INFO - Unable to initialize backend 'plugin': xla_extension has no attributes named get_plugin_device_client. Compile TensorFlow with //tensorflow/compiler/xla/python:enable_plugin_device set to true (defaults to false) to enable this.

# %% [markdown]
# #### Run MCMC inference

# %%
mcmc, posterior_samples = model.run_inference(df=df)
# Out:
# 2023-06-11 23:39:25,525 - __main__ - INFO - Running inference with Mixture_Model ...
#   0%|          | 0/10000 [00:00<?, ?it/s]
#   0%|          | 0/10000 [00:00<?, ?it/s]
#   0%|          | 0/10000 [00:00<?, ?it/s]
#   0%|          | 0/10000 [00:00<?, ?it/s]
# 2023-06-11 23:43:29,741 - hb_mep.utils.utils - INFO - func:run_inference took: 4 min and 4.22 sec

# %% [markdown]
# #### Diagnostics

# %%
mcmc.print_summary(prob=.95)
# Out:
#                            mean       std    median      2.5%     97.5%     n_eff     r_hat
#              a[0,0,0]    124.11      2.78    124.40    118.54    129.04   8381.87      1.00
#              a[0,1,0]    128.66      2.04    128.85    124.43    132.34    728.16      1.01
#              a[0,2,0]    208.01      2.77    208.01    202.79    214.05   9903.53      1.00
#              a[0,3,0]    207.18      3.12    207.27    200.72    213.69  11674.92      1.00
#              a[1,0,0]    166.15      2.94    166.10    160.55    172.57   9294.03      1.00
#   noise_offset[1,2,0]      0.01      0.01      0.01      0.00      0.02   9325.53      1.00
#   noise_offset[1,3,0]      0.01      0.01      0.01      0.00      0.02   5551.31      1.00
# noise_offset_scale[0]      0.01      0.01      0.01      0.00      0.03   9665.10      1.00
#    noise_slope[0,0,0]      0.21      0.03      0.21      0.15      0.28   8883.62      1.00
#    noise_slope[0,1,0]      0.24      0.03      0.24      0.18      0.31   9886.49      1.00
#    noise_slope[0,2,0]      0.24      0.05      0.24      0.15      0.34   5632.70      1.00
#    noise_slope[0,3,0]      0.13      0.04      0.12      0.07      0.20  10224.19      1.00
#    noise_slope[1,0,0]      0.19      0.03      0.18      0.12      0.25   9796.41      1.00
#    noise_slope[1,1,0]      1.78     32.98      0.20      0.00      3.64  11986.61      1.00
#    noise_slope[1,2,0]      0.17      0.08      0.16      0.03      0.32   8534.06      1.00
#    noise_slope[1,3,0]      0.23      0.11      0.24      0.01      0.40   8606.43      1.00
#  noise_slope_scale[0]      0.21      0.09      0.19      0.07      0.38  14542.43      1.00
#              q[0,0,0]      0.01      0.01      0.00      0.00      0.02   7627.75      1.00
#              q[0,1,0]      0.01      0.01      0.00      0.00      0.02   3114.78      1.00
#              q[0,2,0]      0.01      0.00      0.00      0.00      0.02   6277.71      1.00
#              q[0,3,0]      0.01      0.01      0.00      0.00      0.02    243.94      1.01
#              q[1,0,0]      0.01      0.01      0.00      0.00      0.02   4486.83      1.00
#              q[1,1,0]      0.02      0.02      0.01      0.00      0.06  21466.27      1.00
#              q[1,2,0]      0.00      0.00      0.00      0.00      0.01   5159.06      1.00
#              q[1,3,0]      0.01      0.00      0.00      0.00      0.01   4546.62      1.00
#              v[0,0,0]      0.52      0.61      0.33      0.00      1.69   4827.56      1.00
#              v[0,1,0]      0.72      0.91      0.41      0.00      2.46   3523.42      1.00
#              v[0,2,0]      2.15      2.88      1.07      0.00      7.92   2758.16      1.00
#              v[0,3,0]      1.85      2.48      0.94      0.00      6.72   2766.76      1.00
#              v[1,0,0]      2.38      2.96      1.37      0.00      8.18   2918.60      1.00
#              v[1,1,0]      2.23      3.54      0.97      0.00      8.54   3576.05      1.00
#              v[1,2,0]      2.54      3.54      1.22      0.00      9.39   3153.10      1.00
#              v[1,3,0]      2.88      4.37      1.23      0.00     11.32   3848.11      1.00
#            v_scale[0]      2.77      3.01      1.77      0.00      8.82   2260.80      1.00
#
# Number of divergences: 1394

# %% [markdown]
# #### Plot fitted curves

# %%
model.plot(df=df, posterior_samples=posterior_samples);
# Out:
# 2023-06-11 23:44:01,382 - hb_mep.utils.utils - INFO - func:plot took: 31.00 sec

# %% [markdown]
# #### Posterior Predictive

# %%
model.predictive_check(df=df, posterior_samples=posterior_samples);
# Out:
# 2023-06-11 23:44:55,127 - hb_mep.utils.utils - INFO - func:predictive_check took: 49.63 sec

# %% [markdown]
# #### Information Criterion

# %%
numpyro_data = az.from_numpyro(mcmc)

# %% [markdown]
# ##### Loo

# %%
az.loo(numpyro_data)
# Out:
# /home/vishu/repos/hb-mep/.venv/lib/python3.9/site-packages/arviz/stats/stats.py:803: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.7 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# Computed from 24000 posterior samples and 357 observations log-likelihood matrix.
#
#          Estimate       SE
# elpd_loo   562.97    22.83
# p_loo       37.29        -
#
# There has been a warning during the calculation. Please check the results.
# ------
#
# Pareto k diagnostic values:
#                          Count   Pct.
# (-Inf, 0.5]   (good)      346   96.9%
#  (0.5, 0.7]   (ok)          2    0.6%
#    (0.7, 1]   (bad)         8    2.2%
#    (1, Inf)   (very bad)    1    0.3%

# %% [markdown]
# ##### WAIC

# %%
az.waic(numpyro_data)
# Out:
# /home/vishu/repos/hb-mep/.venv/lib/python3.9/site-packages/arviz/stats/stats.py:1645: UserWarning: For one or more samples the posterior variance of the log predictive densities exceeds 0.4. This could be indication of WAIC starting to fail.
# See http://arxiv.org/abs/1507.04544 for details
#   warnings.warn(
# Computed from 24000 posterior samples and 357 observations log-likelihood matrix.
#
#           Estimate       SE
# elpd_waic   565.53    22.74
# p_waic       34.72        -
#
# There has been a warning during the calculation. Please check the results.
