# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import os
import logging
from pathlib import Path

import arviz as az
import numpyro

from hb_mep.config import HBMepConfig
from hb_mep.data_access import DataClass
# from hb_mep.models.rats import MixtureModel
from hb_mep.models.rats.utils import load_data
from hb_mep.utils import plot

numpyro.set_platform("cpu")
numpyro.set_host_device_count(12)
numpyro.enable_x64()

PARENT_PATH = Path(os.getcwd()).parent.parent.absolute()
FORMAT = "%(asctime)s - %(name)s - %(levelname)s - %(message)s"
logging.basicConfig(format=FORMAT, level=logging.INFO)


import jax
import jax.numpy as jnp
import numpy as np
import pandas as pd

import numpyro
import numpyro.distributions as dist
from numpyro.distributions.mixtures import MixtureGeneral
from numpyro.infer import MCMC, NUTS
from numpyro.diagnostics import hpdi

from hb_mep.config import HBMepConfig
from hb_mep.models.baseline import Baseline
from hb_mep.models.utils import Site as site
from hb_mep.utils import timing
from hb_mep.utils.constants import (
    INTENSITY,
    RESPONSE,
    PARTICIPANT,
    FEATURES
)

logger = logging.getLogger(__name__)

# %% [markdown]
# #### Load config

# %%
config = HBMepConfig()
config.CURRENT_PATH = PARENT_PATH

# %% [markdown]
# #### Load data and preprocess

# %%
data = DataClass(config)

a, b = 1, 4
subset = range(a, b)

df, mat, time = load_data(subset, data)
df, encoder_dict = data.build(df)
# Out:
# 2023-06-08 09:11:31,385 - hb_mep.utils.utils - INFO - func:load_data took: 0.40 sec
# 2023-06-08 09:11:31,386 - hb_mep.data_access.core - INFO - Processing data ...
# 2023-06-08 09:11:31,395 - hb_mep.utils.utils - INFO - func:preprocess took: 0.01 sec
# 2023-06-08 09:11:31,395 - hb_mep.utils.utils - INFO - func:build took: 0.01 sec

# %% [markdown]
# ### Mixture Model

# %%
class MixtureModel(Baseline):
    def __init__(self, config: HBMepConfig):
        super(MixtureModel, self).__init__(config=config)
        self.name = "Mixture_Model"

        self.columns = [PARTICIPANT] + FEATURES
        self.x = np.linspace(0, 450, 1000)

    def _model(self, intensity, participant, feature0, feature1, response_obs=None):
        n_data = intensity.shape[0]
        n_participant = np.unique(participant).shape[0]
        n_feature0 = np.unique(feature0).shape[0]
        n_feature1 = np.unique(feature1).shape[0]

        with numpyro.plate("n_participant", n_participant, dim=-1):
            """ Hyper-priors """
            a_mean = numpyro.sample(
                site.a_mean,
                dist.TruncatedDistribution(dist.Normal(150, 50), low=0)
            )
            a_scale = numpyro.sample(site.a_scale, dist.HalfNormal(5))

            b_scale = numpyro.sample(site.b_scale, dist.HalfNormal(0.1))

            h_scale = numpyro.sample("h_scale", dist.HalfNormal(10))
            v_scale = numpyro.sample("v_scale", dist.HalfNormal(10))

            lo_scale = numpyro.sample(site.lo_scale, dist.HalfNormal(0.2))

            with numpyro.plate("n_feature0", n_feature0, dim=-2):
                with numpyro.plate("n_feature1", n_feature1, dim=-3):
                    """ Priors """
                    a = numpyro.sample(
                        site.a,
                        dist.TruncatedDistribution(dist.Normal(a_mean, a_scale), low=0)
                    )
                    b = numpyro.sample(site.b, dist.HalfNormal(b_scale))

                    h = numpyro.sample("h", dist.HalfNormal(h_scale))
                    v = numpyro.sample("v", dist.HalfNormal(v_scale))

                    lo = numpyro.sample(site.lo, dist.HalfNormal(lo_scale))

                    # gamma_scale_offset = numpyro.sample("gamma_scale_offset", dist.Gamma(2, 0.001))
                    # gamma_scale_slope = numpyro.sample("gamma_scale_slope", dist.Gamma(2, 0.001))
                    # gamma_scale_offset = numpyro.sample("gamma_scale_offset", dist.Uniform(0, 1))
                    # gamma_scale_slope = numpyro.sample("gamma_scale_slope", dist.Uniform(0, 1))
                    gamma_scale = numpyro.sample("gamma_scale", dist.Gamma(50, 0.01))

        """ Model """
        mean = numpyro.deterministic(
            site.mean,
            lo[feature1, feature0, participant] + \
            jnp.maximum(
                0,
                -1 + \
                (h[feature1, feature0, participant] + 1) / \
                jnp.power(
                    1 + \
                    (jnp.power(1 + h[feature1, feature0, participant], v[feature1, feature0, participant]) - 1) * \
                    jnp.exp(-b[feature1, feature0, participant] * (intensity - a[feature1, feature0, participant])),
                    1 / v[feature1, feature0, participant]
                )
            )
        )

        # gamma_scale = numpyro.deterministic(
        #     "gamma_scale",
        #     gamma_scale_offset[feature1, feature0, participant] + mean / gamma_scale_slope[feature1, feature0, participant]
        # )
        scale = numpyro.deterministic(
            "scale",
            gamma_scale[feature1, feature0, participant]
        )

        """ Observation """
        with numpyro.plate(site.data, n_data):
            return numpyro.sample(
                site.obs,
                dist.Gamma(mean * scale, scale),
                obs=response_obs
            )

    @timing
    def run_inference(self, df: pd.DataFrame) -> tuple[numpyro.infer.mcmc.MCMC, dict]:
        """
        Run MCMC inference
        """
        response = df[RESPONSE].to_numpy().reshape(-1,)
        participant = df[PARTICIPANT].to_numpy().reshape(-1,)
        feature0 = df[FEATURES[0]].to_numpy().reshape(-1,)
        feature1 = df[FEATURES[1]].to_numpy().reshape(-1,)
        intensity = df[INTENSITY].to_numpy().reshape(-1,)

        # MCMC
        nuts_kernel = NUTS(self._model)
        mcmc = MCMC(nuts_kernel, **self.config.MCMC_PARAMS)
        rng_key = jax.random.PRNGKey(self.random_state)
        logger.info(f"Running inference with {self.name} ...")
        mcmc.run(rng_key, intensity, participant, feature0, feature1, response)
        posterior_samples = mcmc.get_samples()

        return mcmc, posterior_samples

    def _get_estimates(
        self,
        posterior_samples: dict,
        posterior_means: dict,
        c: tuple
    ):
        a = posterior_means[site.a][c[::-1]]
        b = posterior_means[site.b][c[::-1]]
        h = posterior_means["h"][c[::-1]]
        v = posterior_means["v"][c[::-1]]
        lo = posterior_means[site.lo][c[::-1]]

        y = lo + jnp.maximum(
            0,
            -1 + (h + 1) / \
            jnp.power(1 + (jnp.power(1 + h, v) - 1) * jnp.exp(-b * (self.x - a)), 1 / v)
        )

        threshold_samples = posterior_samples[site.a][:, c[2], c[1], c[0]]
        hpdi_interval = hpdi(threshold_samples, prob=0.95)

        return y, a, threshold_samples, hpdi_interval

# %% [markdown]
# #### Initialize model

# %%
model = MixtureModel(config)
# Out:
# 2023-06-08 09:11:31,512 - jax._src.xla_bridge - INFO - Unable to initialize backend 'tpu_driver': NOT_FOUND: Unable to find driver in registry given worker:
# 2023-06-08 09:11:31,512 - jax._src.xla_bridge - INFO - Unable to initialize backend 'cuda': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# 2023-06-08 09:11:31,512 - jax._src.xla_bridge - INFO - Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# 2023-06-08 09:11:31,513 - jax._src.xla_bridge - INFO - Unable to initialize backend 'tpu': INVALID_ARGUMENT: TpuPlatform is not available.
# 2023-06-08 09:11:31,513 - jax._src.xla_bridge - INFO - Unable to initialize backend 'plugin': xla_extension has no attributes named get_plugin_device_client. Compile TensorFlow with //tensorflow/compiler/xla/python:enable_plugin_device set to true (defaults to false) to enable this.

# %% [markdown]
# #### Run MCMC inference

# %%
mcmc, posterior_samples = model.run_inference(df=df)
# Out:
# 2023-06-08 09:11:31,607 - __main__ - INFO - Running inference with Mixture_Model ...
#   0%|          | 0/10000 [00:00<?, ?it/s]
#   0%|          | 0/10000 [00:00<?, ?it/s]
#   0%|          | 0/10000 [00:00<?, ?it/s]
#   0%|          | 0/10000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 mcmc, posterior_samples = model.run_inference(df=df)
#
# File ~/repos/hb-mep/src/hb-mep/hb_mep/utils/utils.py:24, in timing.<locals>.wrap(*args, **kw)
#      21 @wraps(f)
#      22 def wrap(*args, **kw):
#      23     ts = time()
# ---> 24     result = f(*args, **kw)
#      25     te = time()
#      26     time_taken = te - ts
#
# Cell In[5], line 100, in MixtureModel.run_inference(self, df)
#      98 rng_key = jax.random.PRNGKey(self.random_state)
#      99 logger.info(f"Running inference with {self.name} ...")
# --> 100 mcmc.run(rng_key, intensity, participant, feature0, feature1, response)
#     101 posterior_samples = mcmc.get_samples()
#     103 return mcmc, posterior_samples
#
# File ~/repos/hb-mep/.venv/lib/python3.9/site-packages/numpyro/infer/mcmc.py:600, in MCMC.run(self, rng_key, extra_fields, init_params, *args, **kwargs)
#     598     states, last_state = _laxmap(partial_map_fn, map_args)
#     599 elif self.chain_method == "parallel":
# --> 600     states, last_state = pmap(partial_map_fn)(map_args)
#     601 else:
#     602     assert self.chain_method == "vectorized"
#
#     [... skipping hidden 1 frame]
#
# File ~/repos/hb-mep/.venv/lib/python3.9/site-packages/jax/_src/api.py:2390, in _cpp_pmap.<locals>.cache_miss(*args, **kwargs)
#    2388 execute: Optional[Callable] = None
#    2389 if isinstance(top_trace, core.EvalTrace):
# -> 2390   execute = pxla.xla_pmap_impl_lazy(fun_, *tracers, **params)
#    2391   out = map_bind_continuation(execute(*tracers))
#    2392 else:
#
# File ~/repos/hb-mep/.venv/lib/python3.9/site-packages/jax/_src/interpreters/pxla.py:997, in xla_pmap_impl_lazy(fun, backend, axis_name, axis_size, global_axis_size, devices, name, in_axes, out_axes_thunk, donated_invars, global_arg_shapes, is_explicit_global_axis_size, *args)
#     995   return _emap_apply_fn
#     996 abstract_args = unsafe_map(xla.abstractify, args)
# --> 997 compiled_fun, fingerprint = parallel_callable(
#     998     fun, backend, axis_name, axis_size, global_axis_size, devices, name,
#     999     in_axes, out_axes_thunk, donated_invars, global_arg_shapes,
#    1000     is_explicit_global_axis_size, *abstract_args)
#    1002 # Don't re-abstractify args unless logging is enabled for performance.
#    1003 if config.jax_distributed_debug:
#
# File ~/repos/hb-mep/.venv/lib/python3.9/site-packages/jax/_src/linear_util.py:301, in cache.<locals>.memoized_fun(fun, *args)
#     299   fun.populate_stores(stores)
#     300 else:
# --> 301   ans = call(fun, *args)
#     302   cache[key] = (ans, fun.stores)
#     304 return ans
#
# File ~/repos/hb-mep/.venv/lib/python3.9/site-packages/jax/_src/interpreters/pxla.py:1277, in parallel_callable(fun, backend_name, axis_name, axis_size, global_axis_size, devices, name, in_axes, out_axes_thunk, donated_invars, global_arg_shapes, is_explicit_global_axis_size, *avals)
#    1259 @lu.cache
#    1260 def parallel_callable(fun: lu.WrappedFun,
#    1261                       backend_name: Optional[str],
#    (...)
#    1271                       is_explicit_global_axis_size: bool,
#    1272                       *avals):
#    1273   pmap_computation = lower_parallel_callable(
#    1274       fun, backend_name, axis_name, axis_size, global_axis_size, devices, name,
#    1275       in_axes, out_axes_thunk, donated_invars, global_arg_shapes,
#    1276       is_explicit_global_axis_size, avals)
# -> 1277   pmap_executable = pmap_computation.compile()
#    1278   return WeakRefList([pmap_executable.unsafe_call, pmap_executable.fingerprint])
#
# File ~/repos/hb-mep/.venv/lib/python3.9/site-packages/jax/_src/profiler.py:314, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     311 @wraps(func)
#     312 def wrapper(*args, **kwargs):
#     313   with TraceAnnotation(name, **decorator_kwargs):
# --> 314     return func(*args, **kwargs)
#     315   return wrapper
#
# File ~/repos/hb-mep/.venv/lib/python3.9/site-packages/jax/_src/interpreters/pxla.py:1551, in PmapComputation.compile(self)
#    1548 @profiler.annotate_function
#    1549 def compile(self) -> PmapExecutable:
#    1550   if self._executable is None:
# -> 1551     executable = self._compile_unloaded()
#    1552     if isinstance(executable, UnloadedPmapExecutable):
#    1553       executable = executable.load()
#
# File ~/repos/hb-mep/.venv/lib/python3.9/site-packages/jax/_src/interpreters/pxla.py:1532, in PmapComputation._compile_unloaded(self)
#    1531 def _compile_unloaded(self) -> Union[UnloadedPmapExecutable, PmapExecutable]:
# -> 1532   return UnloadedPmapExecutable.from_hlo(self._hlo, **self.compile_args)
#
# File ~/repos/hb-mep/.venv/lib/python3.9/site-packages/jax/_src/interpreters/pxla.py:1689, in UnloadedPmapExecutable.from_hlo(xla_computation, pci, replicas, parts, shards, tuple_args, unordered_effects, ordered_effects, host_callbacks, keepalive)
#    1681   return _compile_replicated_pmap_executable_from_hlo(
#    1682       xla_computation, pci, input_indices, in_shardings, handle_outs,
#    1683       compile_options, host_callbacks, bool(unordered_effects),
#    1684       ordered_effects)
#    1686 with dispatch.log_elapsed_time(
#    1687     f"Finished XLA compilation of {pci.name} in {{elapsed_time}} sec",
#    1688      event=dispatch.BACKEND_COMPILE_EVENT):
# -> 1689   compiled = dispatch.compile_or_get_cached(
#    1690       pci.backend, xla_computation, compile_options, host_callbacks)
#    1692 return UnloadedPmapExecutable(
#    1693     compiled=compiled,
#    1694     backend=pci.backend,
#    (...)
#    1702     host_callbacks=host_callbacks,
#    1703 )
#
# File ~/repos/hb-mep/.venv/lib/python3.9/site-packages/jax/_src/dispatch.py:1085, in compile_or_get_cached(backend, computation, compile_options, host_callbacks)
#    1081     _cache_write(serialized_computation, compile_time, module_name,
#    1082                  compile_options, backend, compiled, host_callbacks)
#    1083     return compiled
# -> 1085 return backend_compile(backend, serialized_computation, compile_options,
#    1086                        host_callbacks)
#
# File ~/repos/hb-mep/.venv/lib/python3.9/site-packages/jax/_src/profiler.py:314, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     311 @wraps(func)
#     312 def wrapper(*args, **kwargs):
#     313   with TraceAnnotation(name, **decorator_kwargs):
# --> 314     return func(*args, **kwargs)
#     315   return wrapper
#
# File ~/repos/hb-mep/.venv/lib/python3.9/site-packages/jax/_src/dispatch.py:1030, in backend_compile(backend, built_c, options, host_callbacks)
#    1025   return backend.compile(built_c, compile_options=options,
#    1026                          host_callbacks=host_callbacks)
#    1027 # Some backends don't have `host_callbacks` option yet
#    1028 # TODO(sharadmv): remove this fallback when all backends allow `compile`
#    1029 # to take in `host_callbacks`
# -> 1030 return backend.compile(built_c, compile_options=options)
#
# KeyboardInterrupt:

# %% [markdown]
# #### Diagnostics

# %%
mcmc.print_summary(prob=.95)
# Out:
#                         mean       std    median      2.5%     97.5%     n_eff     r_hat
#           a[0,0,0]    122.12      2.10    122.12    117.92    126.27  21151.85      1.00
#           a[0,0,1]     50.37      3.91     50.50     42.57     57.99  16567.33      1.00
#           a[0,0,2]     41.40      1.05     41.47     39.31     43.37  19231.27      1.00
#           a[0,1,0]    128.32      2.27    128.31    123.79    132.66  19304.67      1.00
#           a[0,1,1]    120.33      2.49    120.29    115.61    125.22  25946.70      1.00
#           a[0,1,2]    116.29      4.08    115.44    109.63    123.70   5897.28      1.00
#           a[0,2,0]    211.71      3.16    211.22    205.85    217.13  11147.34      1.00
#           a[0,2,1]    229.88      4.69    229.57    220.77    239.47  15763.25      1.00
#           a[0,2,2]    169.30      1.86    169.26    165.69    173.17  20624.87      1.00
#           a[0,3,0]    205.92      1.88    205.88    202.32    209.69  17282.97      1.00
#           a[0,3,1]    280.12      3.73    280.13    273.08    286.99  10103.01      1.00
#           b[1,3,0]      0.00      0.00      0.00      0.00      0.01  11368.41      1.00
#           b[1,3,1]      0.01      0.01      0.01      0.00      0.04   6339.23      1.00
#           b[1,3,2]      0.05      0.02      0.05      0.01      0.10   8786.84      1.00
#         b_scale[0]      0.06      0.02      0.05      0.02      0.11   9708.13      1.00
#         b_scale[1]      0.04      0.02      0.03      0.01      0.08   5420.30      1.00
#         b_scale[2]      0.05      0.02      0.05      0.02      0.10  13132.63      1.00
# gamma_scale[0,0,0]     84.85     10.02     84.49     66.12    104.85  27250.91      1.00
# gamma_scale[0,0,1]     20.03      2.32     19.94     15.55     24.62  27484.94      1.00
# gamma_scale[0,0,2]     91.00     10.72     90.55     71.10    112.75  29883.97      1.00
# gamma_scale[0,1,0]    100.49     11.86     99.95     78.04    124.21  28412.75      1.00
# gamma_scale[0,1,1]     31.67      3.79     31.53     24.34     39.09  27300.44      1.00
# gamma_scale[0,1,2]    107.16     12.46    106.69     82.84    131.44  28195.41      1.00
# gamma_scale[0,2,0]    190.70     22.73    189.75    146.43    234.94  24422.42      1.00
# gamma_scale[0,2,1]     30.42      3.66     30.27     23.48     37.75  25773.97      1.00
# gamma_scale[0,2,2]    149.17     17.43    148.42    115.51    183.46  28054.34      1.00
# gamma_scale[0,3,0]    278.65     32.92    277.62    217.68    345.34  26930.46      1.00
# gamma_scale[0,3,1]     58.39      6.87     58.10     45.16     71.71  27899.83      1.00
# gamma_scale[0,3,2]    151.37     17.80    150.72    116.65    186.41  26907.92      1.00
# gamma_scale[1,0,0]    246.51     28.72    245.59    191.82    303.50  26828.10      1.00
# gamma_scale[1,0,1]     26.70      3.19     26.59     20.79     33.17  28126.32      1.00
# gamma_scale[1,0,2]   4998.89    708.48   4968.03   3681.50   6463.45  27836.46      1.00
# gamma_scale[1,1,0]   4997.54    704.57   4968.09   3628.36   6362.48  30497.43      1.00
# gamma_scale[1,1,1]   5005.03    702.71   4973.56   3696.21   6398.10  29997.28      1.00
# gamma_scale[1,1,2]   4999.65    709.11   4963.58   3629.69   6391.31  29037.79      1.00
# gamma_scale[1,2,0]    361.70     42.64    359.85    277.48    443.54  27544.94      1.00
# gamma_scale[1,2,1]     51.20      6.11     50.95     39.28     63.04  23578.87      1.00
# gamma_scale[1,2,2]    104.95     12.26    104.52     80.96    128.98  27711.65      1.00
# gamma_scale[1,3,0]    347.05     40.32    345.56    269.01    425.60  28401.20      1.00
# gamma_scale[1,3,1]    149.96     17.57    149.34    115.45    183.66  27531.64      1.00
# gamma_scale[1,3,2]    168.63     20.54    167.98    130.01    210.56  19263.45      1.00
#           h[0,0,0]      1.59      0.11      1.58      1.38      1.81  14189.81      1.00
#           h[0,0,1]      4.10      0.15      4.09      3.80      4.40  17138.72      1.00
#           h[0,0,2]      3.26      0.04      3.26      3.18      3.33  22346.16      1.00
#           h[0,1,0]      1.15      0.07      1.15      1.02      1.29  14394.01      1.00
#           h[0,1,1]      3.25      0.26      3.22      2.78      3.75  12942.67      1.00
#           h[0,1,2]      2.18      0.06      2.17      2.06      2.29  14284.90      1.00
#           h[0,2,0]      0.85      0.03      0.84      0.78      0.91   2803.06      1.00
#          lo[1,3,0]      0.05      0.00      0.05      0.04      0.05  24457.01      1.00
#          lo[1,3,1]      0.03      0.00      0.03      0.02      0.03  26365.94      1.00
#          lo[1,3,2]      0.04      0.00      0.04      0.04      0.05  25530.79      1.00
#        lo_scale[0]      0.06      0.02      0.06      0.03      0.10  17220.67      1.00
#        lo_scale[1]      0.05      0.02      0.05      0.02      0.09  16964.33      1.00
#        lo_scale[2]      0.06      0.02      0.05      0.03      0.10  16025.55      1.00
#           v[0,0,0]      0.27      0.27      0.19      0.00      0.79  16900.51      1.00
#           v[0,0,1]      0.62      0.45      0.53      0.00      1.45  10340.36      1.00
#           v[0,0,2]      0.08      0.08      0.05      0.00      0.23  21591.62      1.00
#           v[0,1,0]      0.32      0.32      0.23      0.00      0.95  18145.05      1.00
#           v[0,1,1]      0.46      0.43      0.35      0.00      1.31  10982.86      1.00
#           v[0,1,2]      1.27      0.77      1.20      0.00      2.63   7543.55      1.00
#           v[0,2,0]     13.90      5.17     13.14      5.01     24.55   6712.58      1.00
#           v[0,2,1]      3.13      3.03      2.26      0.00      8.95   5483.14      1.00
#           v[0,2,2]      0.40      0.36      0.31      0.00      1.12  10573.88      1.00
#           v[0,3,0]      9.62      5.79      8.40      0.57     21.35   8038.12      1.00
#           v[0,3,1]      3.02      2.35      2.43      0.01      7.55   5710.46      1.00
#           v[0,3,2]      5.62      2.10      5.29      1.97      9.70   8547.62      1.00
#           v[1,0,0]      7.48      3.61      7.05      1.08     14.50   9678.41      1.00
#           v[1,0,1]      4.88      3.65      3.92      0.02     11.86   5546.56      1.00
#           v[1,0,2]      4.21      4.31      2.96      0.00     12.33  17451.12      1.00
#           v[1,1,0]      8.65      7.88      6.56      0.00     23.90  18110.96      1.00
#           v[1,1,1]      3.68      4.20      2.31      0.00     11.78   9644.16      1.00
#           v[1,1,2]      4.19      4.19      2.96      0.00     12.48  15692.49      1.00
#           v[1,2,0]     11.51      7.58     10.06      0.00     26.15  10694.20      1.00
#           v[1,2,1]      3.97      4.47      2.54      0.00     12.67   6123.84      1.00
#           v[1,2,2]      7.28      4.51      6.19      0.92     16.12   9233.65      1.00
#           v[1,3,0]     12.79      9.44     10.75      0.00     31.36  11370.43      1.00
#           v[1,3,1]      5.51      4.96      4.10      0.00     15.20   6341.49      1.00
#           v[1,3,2]      3.80      3.63      2.77      0.00     10.82  11184.13      1.00
#         v_scale[0]     10.85      4.31     10.19      3.74     19.68   7829.66      1.00
#         v_scale[1]      4.60      3.22      3.76      0.46     11.26   4800.84      1.00
#         v_scale[2]      5.27      2.81      4.60      1.28     10.87   9480.23      1.00
#
# Number of divergences: 172

# %% [markdown]
# #### Plot fitted curves

# %%
model.plot(df=df, posterior_samples=posterior_samples, n_ppd=1000);

# %%
from numpyro.infer import Predictive

# %%
prior_predictive = Predictive(model, num_samples=100)
prior_predictions = prior_predictive(model.rng_key, marriage=dset.MarriageScaled.values)[
    "obs"
]

# %% [markdown]
# #### Information Criterion

# %%
numpyro_data = az.from_numpyro(mcmc)

# %% [markdown]
# ##### Loo

# %%
az.loo(numpyro_data)
# Out:
# /home/vishu/repos/hb-mep/.venv/lib/python3.9/site-packages/arviz/stats/stats.py:1037: RuntimeWarning: overflow encountered in exp
#   weights = 1 / np.exp(len_scale - len_scale[:, None]).sum(axis=1)
# /home/vishu/repos/hb-mep/.venv/lib/python3.9/site-packages/arviz/stats/stats.py:803: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.7 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# Computed from 24000 posterior samples and 1007 observations log-likelihood matrix.
#
#          Estimate       SE
# elpd_loo   573.34   110.11
# p_loo      397.18        -
#
# There has been a warning during the calculation. Please check the results.
# ------
#
# Pareto k diagnostic values:
#                          Count   Pct.
# (-Inf, 0.5]   (good)      927   92.1%
#  (0.5, 0.7]   (ok)         49    4.9%
#    (0.7, 1]   (bad)        24    2.4%
#    (1, Inf)   (very bad)    7    0.7%

# %% [markdown]
# ##### WAIC

# %%
az.waic(numpyro_data)
# Out:
# /home/vishu/repos/hb-mep/.venv/lib/python3.9/site-packages/arviz/stats/stats.py:1645: UserWarning: For one or more samples the posterior variance of the log predictive densities exceeds 0.4. This could be indication of WAIC starting to fail.
# See http://arxiv.org/abs/1507.04544 for details
#   warnings.warn(
# Computed from 24000 posterior samples and 1007 observations log-likelihood matrix.
#
#           Estimate       SE
# elpd_waic   591.10   108.61
# p_waic      379.42        -
#
# There has been a warning during the calculation. Please check the results.
