# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import os
import logging
from pathlib import Path

import arviz as az
import pandas as pd
import numpy as np
import numpyro

from hb_mep.config import HBMepConfig
from hb_mep.data_access import DataClass
from hb_mep.models.relu import ReLU
from hb_mep.utils import plot

numpyro.set_platform("cpu")
numpyro.set_host_device_count(12)
numpyro.enable_x64()

PARENT_PATH = Path(os.getcwd()).parent.absolute()
FORMAT = "%(asctime)s - %(name)s - %(levelname)s - %(message)s"
logging.basicConfig(format=FORMAT, level=logging.INFO)

# %% [markdown]
# #### Load config

# %%
config = HBMepConfig()
config.CURRENT_PATH = PARENT_PATH

# %% [markdown]
# #### Load data and preprocess

# %%
data = DataClass(config)

DATASET_REAL = 'real_data/dnc_info_2022-05-26.parquet'
DATASET_REAL_METADATA = 'dnc_info_2022-05-26_settings.json'

df = pd.read_parquet(os.path.join(data.data_path, DATASET_REAL))
df = data.clean_human_data(df)

# participants = ["cornptio012", "cornptio013", "cornptio015", "scapptio001"]
# idx = df.participant.isin(participants)
# df = df[idx].reset_index(drop=True).copy()

df, encoder_dict = data.build(df)
# Out:
# 2023-05-19 14:29:43,810 - hb_mep.utils.utils - INFO - func:clean_human_data took: 0.08 sec
# 2023-05-19 14:29:43,811 - hb_mep.data_access.core - INFO - Processing data ...
# 2023-05-19 14:29:43,820 - hb_mep.utils.utils - INFO - func:preprocess took: 0.01 sec
# 2023-05-19 14:29:43,820 - hb_mep.utils.utils - INFO - func:build took: 0.01 sec

# %% [markdown]
# #### Plot

# %%
# plot(df=df, encoder_dict=encoder_dict);

# %% [markdown]
# #### Initialize model

# %%
model = ReLU(config)

# %% [markdown]
# #### Run MCMC inference

# %%
mcmc, posterior_samples = model.run_inference(df=df)
# Out:
# 2023-05-19 14:29:44,043 - jax._src.xla_bridge - INFO - Unable to initialize backend 'tpu_driver': NOT_FOUND: Unable to find driver in registry given worker:
# 2023-05-19 14:29:44,044 - jax._src.xla_bridge - INFO - Unable to initialize backend 'cuda': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# 2023-05-19 14:29:44,044 - jax._src.xla_bridge - INFO - Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# 2023-05-19 14:29:44,045 - jax._src.xla_bridge - INFO - Unable to initialize backend 'tpu': INVALID_ARGUMENT: TpuPlatform is not available.
# 2023-05-19 14:29:44,045 - jax._src.xla_bridge - INFO - Unable to initialize backend 'plugin': xla_extension has no attributes named get_plugin_device_client. Compile TensorFlow with //tensorflow/compiler/xla/python:enable_plugin_device set to true (defaults to false) to enable this.
# 2023-05-19 14:29:44,079 - hb_mep.models.relu - INFO - Running inference with ReLU ...
#   0%|          | 0/10000 [00:00<?, ?it/s]
#   0%|          | 0/10000 [00:00<?, ?it/s]
#   0%|          | 0/10000 [00:00<?, ?it/s]
#   0%|          | 0/10000 [00:00<?, ?it/s]
# 2023-05-19 14:34:58,486 - hb_mep.utils.utils - INFO - func:run_inference took: 5 min and 14.45 sec

# %% [markdown]
# #### Diagnostics

# %%
mcmc.print_summary(prob=.95)
# Out:
#                              mean       std    median      2.5%     97.5%     n_eff     r_hat
#                  a[0,0]      0.98      0.87      0.82      0.00      2.19   1662.46      1.00
#                  a[0,1]      1.10      0.15      1.11      0.80      1.39   6091.38      1.00
#                  a[0,2]      2.78      1.42      3.04      0.00      4.75   2382.16      1.00
#                  a[0,3]      3.77      0.31      3.77      3.18      4.39   5101.10      1.00
#                  a[0,4]      2.65      0.58      2.57      1.97      3.26    795.81      1.00
#                  a[0,5]      4.87      3.47      4.50      0.00     10.28   3054.16      1.00
#                  a[0,6]      2.90      0.11      2.91      2.74      3.08   1320.15      1.00
#                  a[0,7]      1.44      0.17      1.47      1.03      1.71   4652.63      1.00
#                  a[0,8]      1.07      0.33      1.07      0.02      1.62     38.29      1.12
#        noise_slope[0,4]      0.19      0.06      0.18      0.06      0.32   1867.41      1.00
#        noise_slope[0,5]      1.26      4.57      0.37      0.00      4.67   3593.25      1.00
#        noise_slope[0,6]      2.49      1.94      1.96      0.74      5.54   3663.51      1.00
#        noise_slope[0,7]      0.44      0.12      0.44      0.19      0.68   3725.24      1.00
#        noise_slope[0,8]      1.02      0.82      0.88      0.00      2.31    117.97      1.04
#        noise_slope[0,9]      0.42      0.06      0.41      0.32      0.52   6334.40      1.00
#       noise_slope[0,10]      0.12      0.01      0.12      0.10      0.15   6034.47      1.00
#       noise_slope[0,11]      0.70      0.48      0.61      0.27      1.33   1111.73      1.00
#       noise_slope[0,12]      0.33      0.04      0.32      0.26      0.40   6413.54      1.00
#        noise_slope[1,0]      0.18      0.06      0.18      0.05      0.32   2442.10      1.00
#        noise_slope[1,1]      0.50      0.15      0.47      0.28      0.80   3274.93      1.00
#        noise_slope[1,2]      0.18      0.06      0.18      0.07      0.29   5404.00      1.00
#        noise_slope[1,3]      0.16      0.07      0.15      0.04      0.31   3529.83      1.00
#        noise_slope[1,4]      1.94      2.16      1.41      0.25      4.89   4742.07      1.00
#        noise_slope[1,5]      0.15      0.08      0.15      0.00      0.27   4805.61      1.00
#        noise_slope[1,6]      0.66      0.17      0.62      0.43      0.96   1485.94      1.00
#        noise_slope[1,7]      0.39      0.08      0.38      0.27      0.55   1760.34      1.00
#        noise_slope[1,8]      0.58      0.43      0.47      0.24      1.17   2148.65      1.00
#        noise_slope[1,9]      0.27      0.05      0.27      0.16      0.38   2408.61      1.00
#       noise_slope[1,10]      0.08      0.01      0.08      0.07      0.09   8907.96      1.00
#       noise_slope[1,11]      0.09      0.01      0.09      0.06      0.12   2952.55      1.00
#       noise_slope[1,12]      0.43      0.22      0.38      0.22      0.71    226.89      1.02
#
# Number of divergences: 3824

# %% [markdown]
# #### Information Criterion

# %%
numpyro_data = az.from_numpyro(mcmc)

# %%
az.loo(numpyro_data)
# Out:
# /home/vishu/repos/hb-mep/.venv/lib/python3.9/site-packages/arviz/stats/stats.py:1037: RuntimeWarning: overflow encountered in exp
#   weights = 1 / np.exp(len_scale - len_scale[:, None]).sum(axis=1)
# /home/vishu/repos/hb-mep/.venv/lib/python3.9/site-packages/numpy/core/_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/vishu/repos/hb-mep/.venv/lib/python3.9/site-packages/arviz/stats/stats.py:803: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.7 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# Computed from 24000 posterior samples and 1165 observations log-likelihood matrix.
#
#          Estimate       SE
# elpd_loo   724.13    89.56
# p_loo      174.16        -
#
# There has been a warning during the calculation. Please check the results.
# ------
#
# Pareto k diagnostic values:
#                          Count   Pct.
# (-Inf, 0.5]   (good)     1102   94.6%
#  (0.5, 0.7]   (ok)         24    2.1%
#    (0.7, 1]   (bad)         8    0.7%
#    (1, Inf)   (very bad)   31    2.7%

# %%
az.waic(numpyro_data)
# Out:
# /home/vishu/repos/hb-mep/.venv/lib/python3.9/site-packages/arviz/stats/stats.py:1645: UserWarning: For one or more samples the posterior variance of the log predictive densities exceeds 0.4. This could be indication of WAIC starting to fail.
# See http://arxiv.org/abs/1507.04544 for details
#   warnings.warn(
# Computed from 24000 posterior samples and 1165 observations log-likelihood matrix.
#
#           Estimate       SE
# elpd_waic   740.92    88.59
# p_waic      157.37        -
#
# There has been a warning during the calculation. Please check the results.

# %% [markdown]
# #### Plot fitted curves

# %%
model.plot(df=df, posterior_samples=posterior_samples);
